# %%
import pandas as pd
import os

# %% [markdown]
# # Load Raw Data

# %%
raw_path = "../data/raw/"
files = [file for file in os.listdir(raw_path) if file.endswith(".csv")]

df = pd.DataFrame()
for file in files:
    temp_df = pd.read_csv(os.path.join(raw_path, file))
    df = pd.concat([df, temp_df], ignore_index=True)

df
# Out:
#                 ID                                             Título  \
# 0      103182800.0        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 1      103182800.0        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 2      103813549.0  Ático en calle Calderón de la Barca, 6, Centro...
# 3      103182800.0        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 4      103813549.0  Ático en calle Calderón de la Barca, 6, Centro...
# ...            ...                                                ...
# 95423    104392000  Piso en avenida de les Corts Valencianes, Sant...
# 95424    106561686        Piso en El Cabanyal-El Canyamelar, València
# 95425    105731411                          Piso en El Grau, València
# 95426    104242821  Piso en calle del Pare Jofré, La Roqueta, Valè...
# 95427     96126297  Dúplex en calle dels Tomasos, 20, Russafa, Val...
#
#                                               Enlace      Precio  \
# 0      https://www.idealista.com/inmueble/103182800/    545.000€
# 1      https://www.idealista.com/inmueble/103182800/    545.000€
# 2      https://www.idealista.com/inmueble/103813549/    324.000€
# 3      https://www.idealista.com/inmueble/103182800/    545.000€
# 4      https://www.idealista.com/inmueble/103813549/    324.000€
# ...                                              ...         ...
# 95423  https://www.idealista.com/inmueble/104392000/  1.250.000€
# 95424  https://www.idealista.com/inmueble/106561686/    289.000€
# 95425  https://www.idealista.com/inmueble/105731411/    525.000€
# 95426  https://www.idealista.com/inmueble/104242821/    325.000€
# 95427   https://www.idealista.com/inmueble/96126297/  1.200.000€
#
#                                                 Detalles  \
# 0      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 1      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 2       2 hab. | 72 m² | Planta 5ª exterior con ascensor
# 3      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 4       2 hab. | 72 m² | Planta 5ª exterior con ascensor
# ...                                                  ...
# 95423  3 hab. | 225 m² | Planta 15ª exterior con asce...
# 95424  4 hab. | 110 m² | Planta 4ª exterior con ascensor
# 95425            5 hab. | 181 m² | exterior con ascensor
# 95426        2 hab. | 42 m² | Bajo exterior sin ascensor
# 95427       5 hab. | 317 m² | Bajo exterior sin ascensor
#
#                                              Descripción
# 0      Magnifico piso situado en una zona privilegiad...
# 1      Magnifico piso situado en una zona privilegiad...
# 2      ATICO EN EL CENTRO HISTORICO DE MÁLAGA.\nEste ...
# 3      Magnifico piso situado en una zona privilegiad...
# 4      ATICO EN EL CENTRO HISTORICO DE MÁLAGA.\nEste ...
# ...                                                  ...
# 95423  EXCLUSIVO PISO DE LUJO EN EDIFICIO "IKON"\nINM...
# 95424  Lion Capital Group le ofrece está increíble op...
# 95425  Piso exterior con 5 dormitorios en J. J. Domin...
# 95426  LOFT EN VENTA CON LICENCIA TURÍSTICA EN LA ROQ...
# 95427  Disponible desde septiembre!\nExcepcional y ex...
#
# [95428 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Título', 'Enlace', 'Precio', 'Detalles', 'Descripción'], dtype='object')

# %%
df.describe()
# Out:
#                ID         Título         Enlace         Precio       Detalles  \
# count       89178          95428          95428          95428          95428
# unique        509            364            510            255            480
# top     105435068  No disponible  No disponible  No disponible  No disponible
# freq          812           6250           6250           6250           6250
#
#           Descripción
# count           95428
# unique            513
# top     No disponible
# freq             6250

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95428 entries, 0 to 95427
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           89178 non-null  object
#  1   Título       95428 non-null  object
#  2   Enlace       95428 non-null  object
#  3   Precio       95428 non-null  object
#  4   Detalles     95428 non-null  object
#  5   Descripción  95428 non-null  object
# dtypes: object(6)
# memory usage: 4.4+ MB

# %%
len(df["ID"].unique())
# Out:
# 510

# %%
df.isna().sum()
# Out:
# ID             6250
# Título            0
# Enlace            0
# Precio            0
# Detalles          0
# Descripción       0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#                 ID                                             Título  \
# 0      103182800.0        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 1      103182800.0        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 2      103813549.0  Ático en calle Calderón de la Barca, 6, Centro...
# 3      103182800.0        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 4      103813549.0  Ático en calle Calderón de la Barca, 6, Centro...
# ...            ...                                                ...
# 95423    104392000  Piso en avenida de les Corts Valencianes, Sant...
# 95424    106561686        Piso en El Cabanyal-El Canyamelar, València
# 95425    105731411                          Piso en El Grau, València
# 95426    104242821  Piso en calle del Pare Jofré, La Roqueta, Valè...
# 95427     96126297  Dúplex en calle dels Tomasos, 20, Russafa, Val...
#
#                                               Enlace      Precio  \
# 0      https://www.idealista.com/inmueble/103182800/    545.000€
# 1      https://www.idealista.com/inmueble/103182800/    545.000€
# 2      https://www.idealista.com/inmueble/103813549/    324.000€
# 3      https://www.idealista.com/inmueble/103182800/    545.000€
# 4      https://www.idealista.com/inmueble/103813549/    324.000€
# ...                                              ...         ...
# 95423  https://www.idealista.com/inmueble/104392000/  1.250.000€
# 95424  https://www.idealista.com/inmueble/106561686/    289.000€
# 95425  https://www.idealista.com/inmueble/105731411/    525.000€
# 95426  https://www.idealista.com/inmueble/104242821/    325.000€
# 95427   https://www.idealista.com/inmueble/96126297/  1.200.000€
#
#                                                 Detalles  \
# 0      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 1      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 2       2 hab. | 72 m² | Planta 5ª exterior con ascensor
# 3      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 4       2 hab. | 72 m² | Planta 5ª exterior con ascensor
# ...                                                  ...
# 95423  3 hab. | 225 m² | Planta 15ª exterior con asce...
# 95424  4 hab. | 110 m² | Planta 4ª exterior con ascensor
# 95425            5 hab. | 181 m² | exterior con ascensor
# 95426        2 hab. | 42 m² | Bajo exterior sin ascensor
# 95427       5 hab. | 317 m² | Bajo exterior sin ascensor
#
#                                              Descripción
# 0      Magnifico piso situado en una zona privilegiad...
# 1      Magnifico piso situado en una zona privilegiad...
# 2      ATICO EN EL CENTRO HISTORICO DE MÁLAGA.\nEste ...
# 3      Magnifico piso situado en una zona privilegiad...
# 4      ATICO EN EL CENTRO HISTORICO DE MÁLAGA.\nEste ...
# ...                                                  ...
# 95423  EXCLUSIVO PISO DE LUJO EN EDIFICIO "IKON"\nINM...
# 95424  Lion Capital Group le ofrece está increíble op...
# 95425  Piso exterior con 5 dormitorios en J. J. Domin...
# 95426  LOFT EN VENTA CON LICENCIA TURÍSTICA EN LA ROQ...
# 95427  Disponible desde septiembre!\nExcepcional y ex...
#
# [89178 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89178 entries, 0 to 95427
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           89178 non-null  object
#  1   Título       89178 non-null  object
#  2   Enlace       89178 non-null  object
#  3   Precio       89178 non-null  object
#  4   Detalles     89178 non-null  object
#  5   Descripción  89178 non-null  object
# dtypes: object(6)
# memory usage: 4.8+ MB

# %% [markdown]
# # Feature Engineering
# Creación de nuevas features a partir de las existentes

# %% [markdown]
# ## ID
# must be numeric (int)

# %%
df["ID"] = pd.to_numeric(df["ID"], errors='coerce').astype('Int64')
df["ID"]
# Out:
# 0        103182800
# 1        103182800
# 2        103813549
# 3        103182800
# 4        103813549
#            ...
# 95423    104392000
# 95424    106561686
# 95425    105731411
# 95426    104242821
# 95427     96126297
# Name: ID, Length: 89178, dtype: Int64

# %%
df["ID"].isna().sum()
# Out:
# 4

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## Detalles
# Se puede extraer el numero de habitaciones, los metros, la planta, booleano de si t iene ascensor o no....

# %%
df["Detalles"][0]
# Out:
# '5 hab. | 145 m² | Planta 8ª exterior con ascensor'

# %%
splits = df["Detalles"][0].split("|")
splits
# Out:
# ['5 hab. ', ' 145 m² ', ' Planta 8ª exterior con ascensor']

# %%
for split in splits:
    print(split)
# Out:
# 5 hab.
#  145 m²
#  Planta 8ª exterior con ascensor

# %%
def get_number_of_rooms(df: pd.DataFrame) -> pd.DataFrame:
    df_new = df.copy()
    df_new["rooms"] = df_new["Detalles"].str.extract(r'(\d+) hab\.')
    return df_new

def get_meters(df: pd.DataFrame) -> pd.DataFrame:
    df_new = df.copy()
    df_new["meters"] = df_new["Detalles"].str.extract(r"(\d+) m² ")
    return df_new

def get_elevator(df: pd.DataFrame) -> pd.DataFrame:
    df_new = df.copy()
    df_new["Elevator"] = df_new["Detalles"].str.contains("con ascensor", case=False, na=False)
    return df_new

def get_floor(df: pd.DataFrame) -> pd.DataFrame:
    df_new = df.copy()
    # Extrae el número de planta, antes de "ª"
    df_new["Floor"] = df_new["Detalles"].str.extract(r"(\d+)ª")[0]
    return df_new

# %%
df = get_floor(get_elevator(get_number_of_rooms(get_meters(df))))
df
# Out:
#               ID                                             Título  \
# 0      103182800        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 1      103182800        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 2      103813549  Ático en calle Calderón de la Barca, 6, Centro...
# 3      103182800        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 4      103813549  Ático en calle Calderón de la Barca, 6, Centro...
# ...          ...                                                ...
# 95423  104392000  Piso en avenida de les Corts Valencianes, Sant...
# 95424  106561686        Piso en El Cabanyal-El Canyamelar, València
# 95425  105731411                          Piso en El Grau, València
# 95426  104242821  Piso en calle del Pare Jofré, La Roqueta, Valè...
# 95427   96126297  Dúplex en calle dels Tomasos, 20, Russafa, Val...
#
#                                               Enlace      Precio  \
# 0      https://www.idealista.com/inmueble/103182800/    545.000€
# 1      https://www.idealista.com/inmueble/103182800/    545.000€
# 2      https://www.idealista.com/inmueble/103813549/    324.000€
# 3      https://www.idealista.com/inmueble/103182800/    545.000€
# 4      https://www.idealista.com/inmueble/103813549/    324.000€
# ...                                              ...         ...
# 95423  https://www.idealista.com/inmueble/104392000/  1.250.000€
# 95424  https://www.idealista.com/inmueble/106561686/    289.000€
# 95425  https://www.idealista.com/inmueble/105731411/    525.000€
# 95426  https://www.idealista.com/inmueble/104242821/    325.000€
# 95427   https://www.idealista.com/inmueble/96126297/  1.200.000€
#
#                                                 Detalles  \
# 0      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 1      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 2       2 hab. | 72 m² | Planta 5ª exterior con ascensor
# 3      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 4       2 hab. | 72 m² | Planta 5ª exterior con ascensor
# ...                                                  ...
# 95423  3 hab. | 225 m² | Planta 15ª exterior con asce...
# 95424  4 hab. | 110 m² | Planta 4ª exterior con ascensor
# 95425            5 hab. | 181 m² | exterior con ascensor
# 95426        2 hab. | 42 m² | Bajo exterior sin ascensor
# 95427       5 hab. | 317 m² | Bajo exterior sin ascensor
#
#                                              Descripción      price meters  \
# 0      Magnifico piso situado en una zona privilegiad...   545000.0    145
# 1      Magnifico piso situado en una zona privilegiad...   545000.0    145
# 2      ATICO EN EL CENTRO HISTORICO DE MÁLAGA.\nEste ...   324000.0     72
# 3      Magnifico piso situado en una zona privilegiad...   545000.0    145
# 4      ATICO EN EL CENTRO HISTORICO DE MÁLAGA.\nEste ...   324000.0     72
# ...                                                  ...        ...    ...
# 95423  EXCLUSIVO PISO DE LUJO EN EDIFICIO "IKON"\nINM...  1250000.0    225
# 95424  Lion Capital Group le ofrece está increíble op...   289000.0    110
# 95425  Piso exterior con 5 dormitorios en J. J. Domin...   525000.0    181
# 95426  LOFT EN VENTA CON LICENCIA TURÍSTICA EN LA ROQ...   325000.0     42
# 95427  Disponible desde septiembre!\nExcepcional y ex...  1200000.0    317
#
#       rooms  Elevator Floor
# 0         5      True     8
# 1         5      True     8
# 2         2      True     5
# 3         5      True     8
# 4         2      True     5
# ...     ...       ...   ...
# 95423     3      True    15
# 95424     4      True     4
# 95425     5      True   NaN
# 95426     2     False   NaN
# 95427     5     False   NaN
#
# [89174 rows x 11 columns]

# %% [markdown]
# ## Price

# %%
df['price'] = df["Precio"].str.replace("€", "").str.replace(".", "").str.replace(",", ".").astype(float)
df["price"]
# Out:
# 0         545000.0
# 1         545000.0
# 2         324000.0
# 3         545000.0
# 4         324000.0
#            ...
# 95423    1250000.0
# 95424     289000.0
# 95425     525000.0
# 95426     325000.0
# 95427    1200000.0
# Name: price, Length: 89174, dtype: float64

# %% [markdown]
# ## Property type

# %%
def get_property_type(df: pd.DataFrame) -> pd.DataFrame:
    df_new = df.copy()
    df_new["PropertyType"] = df_new["Detalles"].str.extract(r'(piso|ático|dúplex|chalet)')[0]
    return df_new

# %%
df = get_property_type(df)
df
# Out:
#               ID                                             Título  \
# 0      103182800        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 1      103182800        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 2      103813549  Ático en calle Calderón de la Barca, 6, Centro...
# 3      103182800        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 4      103813549  Ático en calle Calderón de la Barca, 6, Centro...
# ...          ...                                                ...
# 95423  104392000  Piso en avenida de les Corts Valencianes, Sant...
# 95424  106561686        Piso en El Cabanyal-El Canyamelar, València
# 95425  105731411                          Piso en El Grau, València
# 95426  104242821  Piso en calle del Pare Jofré, La Roqueta, Valè...
# 95427   96126297  Dúplex en calle dels Tomasos, 20, Russafa, Val...
#
#                                               Enlace      Precio  \
# 0      https://www.idealista.com/inmueble/103182800/    545.000€
# 1      https://www.idealista.com/inmueble/103182800/    545.000€
# 2      https://www.idealista.com/inmueble/103813549/    324.000€
# 3      https://www.idealista.com/inmueble/103182800/    545.000€
# 4      https://www.idealista.com/inmueble/103813549/    324.000€
# ...                                              ...         ...
# 95423  https://www.idealista.com/inmueble/104392000/  1.250.000€
# 95424  https://www.idealista.com/inmueble/106561686/    289.000€
# 95425  https://www.idealista.com/inmueble/105731411/    525.000€
# 95426  https://www.idealista.com/inmueble/104242821/    325.000€
# 95427   https://www.idealista.com/inmueble/96126297/  1.200.000€
#
#                                                 Detalles  \
# 0      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 1      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 2       2 hab. | 72 m² | Planta 5ª exterior con ascensor
# 3      5 hab. | 145 m² | Planta 8ª exterior con ascensor
# 4       2 hab. | 72 m² | Planta 5ª exterior con ascensor
# ...                                                  ...
# 95423  3 hab. | 225 m² | Planta 15ª exterior con asce...
# 95424  4 hab. | 110 m² | Planta 4ª exterior con ascensor
# 95425            5 hab. | 181 m² | exterior con ascensor
# 95426        2 hab. | 42 m² | Bajo exterior sin ascensor
# 95427       5 hab. | 317 m² | Bajo exterior sin ascensor
#
#                                              Descripción      price meters  \
# 0      Magnifico piso situado en una zona privilegiad...   545000.0    145
# 1      Magnifico piso situado en una zona privilegiad...   545000.0    145
# 2      ATICO EN EL CENTRO HISTORICO DE MÁLAGA.\nEste ...   324000.0     72
# 3      Magnifico piso situado en una zona privilegiad...   545000.0    145
# 4      ATICO EN EL CENTRO HISTORICO DE MÁLAGA.\nEste ...   324000.0     72
# ...                                                  ...        ...    ...
# 95423  EXCLUSIVO PISO DE LUJO EN EDIFICIO "IKON"\nINM...  1250000.0    225
# 95424  Lion Capital Group le ofrece está increíble op...   289000.0    110
# 95425  Piso exterior con 5 dormitorios en J. J. Domin...   525000.0    181
# 95426  LOFT EN VENTA CON LICENCIA TURÍSTICA EN LA ROQ...   325000.0     42
# 95427  Disponible desde septiembre!\nExcepcional y ex...  1200000.0    317
#
#       rooms  Elevator Floor PropertyType
# 0         5      True     8          NaN
# 1         5      True     8          NaN
# 2         2      True     5          NaN
# 3         5      True     8          NaN
# 4         2      True     5          NaN
# ...     ...       ...   ...          ...
# 95423     3      True    15          NaN
# 95424     4      True     4          NaN
# 95425     5      True   NaN          NaN
# 95426     2     False   NaN          NaN
# 95427     5     False   NaN          NaN
#
# [89174 rows x 12 columns]

# %%
df["PropertyType"].unique()
# Out:
# array([nan], dtype=object)

# %% [markdown]
# # DF Final

# %%
df.drop(columns=["Detalles"])
# Out:
#               ID                                             Título  \
# 0      103182800        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 1      103182800        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 2      103813549  Ático en calle Calderón de la Barca, 6, Centro...
# 3      103182800        Piso en calle Ferrándiz, Gibralfaro, Málaga
# 4      103813549  Ático en calle Calderón de la Barca, 6, Centro...
# ...          ...                                                ...
# 95423  104392000  Piso en avenida de les Corts Valencianes, Sant...
# 95424  106561686        Piso en El Cabanyal-El Canyamelar, València
# 95425  105731411                          Piso en El Grau, València
# 95426  104242821  Piso en calle del Pare Jofré, La Roqueta, Valè...
# 95427   96126297  Dúplex en calle dels Tomasos, 20, Russafa, Val...
#
#                                               Enlace      Precio  \
# 0      https://www.idealista.com/inmueble/103182800/    545.000€
# 1      https://www.idealista.com/inmueble/103182800/    545.000€
# 2      https://www.idealista.com/inmueble/103813549/    324.000€
# 3      https://www.idealista.com/inmueble/103182800/    545.000€
# 4      https://www.idealista.com/inmueble/103813549/    324.000€
# ...                                              ...         ...
# 95423  https://www.idealista.com/inmueble/104392000/  1.250.000€
# 95424  https://www.idealista.com/inmueble/106561686/    289.000€
# 95425  https://www.idealista.com/inmueble/105731411/    525.000€
# 95426  https://www.idealista.com/inmueble/104242821/    325.000€
# 95427   https://www.idealista.com/inmueble/96126297/  1.200.000€
#
#                                              Descripción      price
# 0      Magnifico piso situado en una zona privilegiad...   545000.0
# 1      Magnifico piso situado en una zona privilegiad...   545000.0
# 2      ATICO EN EL CENTRO HISTORICO DE MÁLAGA.\nEste ...   324000.0
# 3      Magnifico piso situado en una zona privilegiad...   545000.0
# 4      ATICO EN EL CENTRO HISTORICO DE MÁLAGA.\nEste ...   324000.0
# ...                                                  ...        ...
# 95423  EXCLUSIVO PISO DE LUJO EN EDIFICIO "IKON"\nINM...  1250000.0
# 95424  Lion Capital Group le ofrece está increíble op...   289000.0
# 95425  Piso exterior con 5 dormitorios en J. J. Domin...   525000.0
# 95426  LOFT EN VENTA CON LICENCIA TURÍSTICA EN LA ROQ...   325000.0
# 95427  Disponible desde septiembre!\nExcepcional y ex...  1200000.0
#
# [89174 rows x 6 columns]

# %%
df["Descripción"][0:4]
# Out:
# 0    Magnifico piso situado en una zona privilegiad...
# 1    Magnifico piso situado en una zona privilegiad...
# 2    ATICO EN EL CENTRO HISTORICO DE MÁLAGA.\nEste ...
# 3    Magnifico piso situado en una zona privilegiad...
# Name: Descripción, dtype: object
