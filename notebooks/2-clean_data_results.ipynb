# %% [markdown]
# Results from script "clean_data.py"

# %%
import pandas as pd

# %%
path = "../data/processed/cleaned_data-barcelona.csv"
df = pd.read_csv(path)
df
# Out:
#             ID                                             Título  \
# 0    103739782  Piso en calle de Ferrán Agulló, Sant Gervasi -...
# 1    105473433  Piso en calle de València, La Dreta de l'Eixam...
# 2    103930029  Ático en Gran Via de les Corts Catalanes, L'An...
# 3    105043094  Piso en paseo de Gràcia, La Dreta de l'Eixampl...
# 4    103305568  Casa o chalet independiente en calle de Benede...
# ..         ...                                                ...
# 353  100686482  Dúplex en calle D'Abdó Terradas, Vila de Gràci...
# 354  102256338  Piso en rambla de Catalunya, La Dreta de l'Eix...
# 355  103780867  Piso en calle de Casp, La Dreta de l'Eixample,...
# 356  101913750  Chalet adosado en Passatge de Maria Llimona, D...
# 357  101781007    Piso en avenida Pedralbes, Pedralbes, Barcelona
#
#                                             Enlace      Precio  \
# 0    https://www.idealista.com/inmueble/103739782/  1.560.000€
# ...

# %% [markdown]
# El dataset que se obtiene tras la limpieza tiene las mismas entradas que usando la función `apply_pipeline` de `src/pipeline.py`
