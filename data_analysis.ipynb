# %%
import pandas as pd

# %%
# df = pd.read_csv("scraped_data-barcelona.csv")
df = pd.read_csv("data/data.csv")
df
# Out:
#       Unnamed: 0           ID  \
# 0              0  106476051.0
# 1              1  106475860.0
# 2              2  103930029.0
# 3              3          NaN
# 4              4  105473433.0
# ...          ...          ...
# 1915        1915  101127298.0
# 1916        1916  105967284.0
# 1917        1917  106286767.0
# 1918        1918  106436932.0
# 1919        1919  106379239.0
#
#                                                  Título  \
# 0           Piso en paseo de Colom, El Gòtic, Barcelona
# 1        Piso en calle de la Mercè, El Gòtic, Barcelona
# 2     Ático en Gran Via de les Corts Catalanes, L'An...
# 3                                         No disponible
# 4     Piso en calle de València, La Dreta de l'Eixam...
# ...                                                 ...
# 1915  Piso en El Poble Sec - Parc de Montjuïc, Barce...
# 1916  Piso en calle de la Junta de Comerç, El Raval,...
# 1917                      Piso en La Sagrera, Barcelona
# ...

# %%
df = df.drop(columns=df.columns[0]).drop_duplicates(subset=["ID"], keep="first")
df
# Out:
#                ID                                             Título  \
# 0     106476051.0        Piso en paseo de Colom, El Gòtic, Barcelona
# 1     106475860.0     Piso en calle de la Mercè, El Gòtic, Barcelona
# 2     103930029.0  Ático en Gran Via de les Corts Catalanes, L'An...
# 3             NaN                                      No disponible
# 4     105473433.0  Piso en calle de València, La Dreta de l'Eixam...
# ...           ...                                                ...
# 1915  101127298.0  Piso en El Poble Sec - Parc de Montjuïc, Barce...
# 1916  105967284.0  Piso en calle de la Junta de Comerç, El Raval,...
# 1917  106286767.0                      Piso en La Sagrera, Barcelona
# 1918  106436932.0                        Piso en Can Baró, Barcelona
# 1919  106379239.0                Piso en La Trinitat Nova, Barcelona
#
#                                              Enlace         Precio  \
# 0     https://www.idealista.com/inmueble/106476051/     1.275.000€
# ...

# %%
df.to_csv("data/data_unique.csv")

# %%
df["Precio"].unique()
# Out:
# array(['750.000€', '765.000€', '1.275.000€', 'No disponible',
#        '2.450.000€', '1.350.000€', '1.150.000€', '2.500.000€', '695.000€',
#        '2.000.000€', '1.380.000€', '2.755.000€', '2.995.000€',
#        '2.550.000€', '1.545.000€', '1.200.000€', '1.640.000€',
#        '2.380.000€', '1.900.000€', '995.000€', '675.000€', '1.595.000€',
#        '1.240.000€', '4.950.000€', '1.690.000€', '1.995.000€', '990.000€',
#        '820.000€', '875.000€', '2.420.000€', '749.000€', '730.000€',
#        '1.270.000€', '1.600.000€', '1.580.000€', '550.000€', '650.000€',
#        '1.430.000€', '1.790.000€', '1.425.000€', '2.200.000€',
#        '3.200.000€', '2.400.000€', '895.000€', '1.250.000€', '1.190.000€',
#        '1.550.000€', '950.000€', '2.996.000€', '900.000€', '1.050.000€',
#        '1.345.000€', '1.850.000€', '560.000€', '1.700.000€', '899.000€',
#        '470.000€', '630.000€', '3.790.000€', '1.290.000€', '740.000€',
# ...
